# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Import required libraries and read the dataset.

# %%
df=pd.read_csv('honeyproduction.csv')
df
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
df1=df.copy()

# %%
df1
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
df1.shape
# Out:
# (626, 8)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
df1.dtypes
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
df1.isnull().sum()
# Out:
# state          0
# numcol         0
# yieldpercol    0
# totalprod      0
# stocks         0
# priceperlb     0
# prodvalue      0
# year           0
# dtype: int64

# %% [markdown]
# 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
x=df1.groupby(by=['year']).size()/len(df1)*100
x
# Out:
# year
# 1998    6.869010
# 1999    6.869010
# 2000    6.869010
# 2001    7.028754
# 2002    7.028754
# 2003    7.028754
# 2004    6.549521
# 2005    6.549521
# 2006    6.549521
# 2007    6.549521
# 2008    6.549521
# 2009    6.389776
# 2010    6.389776
# 2011    6.389776
# 2012    6.389776
# dtype: float64

# %%
plt.pie(x,labels=x.index,autopct='%1.1f%%');
plt.title('percentage distribution of the data in each year ');

# %% [markdown]
# 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
df1.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
sns.displot(df1['priceperlb']);
# Out:
# C:\Users\rajsk\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# INFERENCE:
#     Our majority of data is before the mean(1.409569), our median(1.360000) is before the mean, and it has positive skewness. Our majority of data is between the range (0.7 to 2)

# %% [markdown]
# 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and
# write your findings.

# %%
sns.scatterplot(x=df1['numcol'],y=df1['prodvalue']);
plt.title(' Relationship between the variables numcol and prodvalue through scatterplot');

# %% [markdown]
# INFERENCE:
#     Because there is linear growth between them, there is a positive link between the number of colonies and the production value. The majority of data falls between 0 and 100,000.

# %% [markdown]
# 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable
# 'prodvalue' through boxplot, and write your findings.

# %%
df1.dtypes
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
sns.boxplot(x=df1['year'],y=df1['prodvalue']);
plt.title('relationship between categorical variable year and a numerical variable prodvalue through boxplot');

# %% [markdown]
# INFERENCE:
#     The 2003,2008,2009,2010,2012 has the more outliers and the 2010 has the highest outliers. Almost majority of the years have the same range of mean.

# %% [markdown]
# 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years
# using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(df1,vars=['numcol', 'yieldpercol', 'totalprod', 'prodvalue','year']);
plt.title('Relationship between the multiple pairs of variables')
# Out:
# C:\Users\rajsk\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Relationship between the multiple pairs of variables')

# %% [markdown]
# INFERENCE:
#     Some of the pairs have no association, such as (yieldpercol,numcol), (prodvalue, yieldpercol), and (yieldpercol,totalprod). These pairs have a positive correlation because as the x axis increases, so does the y axis. Thus the two variables (totalprod,numcol), (prodvalue,numcol), and (totalprod,prodvalue) are all flowing in the same direction.

# %% [markdown]
# 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol',
# 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
df1[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']]
sns.heatmap(df1[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']]
.corr(),annot=True);

# %% [markdown]
# INFERENCE:
#     The correlation value is high for the totalprod and numcol(0.95). The least positive correlation is between the totalprod and the yieldpercol(0.4). There is also some negatively correlated pairs they are mostly pair with the priceperlb such as numcol, yieldpercol,totalprod ,prodvalue and stocks .
